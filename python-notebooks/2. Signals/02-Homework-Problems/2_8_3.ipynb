# %% [markdown]
# # === Cell 1 - Metadata ===

# %% [markdown]
# ### Course: Signals and Systems — Programming Section (Python)
#
# **Full Name:**Mohammad mahdi maazalahi
#
# **Student ID:**401121733
#
# **Source:** *Signals and Systems Laboratory with MATLAB*
# **Problem Number (Chapter.section.question_num):**2.8.3

# %% [markdown]
# # === Cell 2 - Upload & display question image :===

# %% [markdown]
# ## Problem Statement (Image)
# Please paste the screenshot of the original problem statement in the space below.
# The image must clearly show the problem number, text, and any figures or diagrams included in the textbook.
#
# <!-- Paste the screenshot of the problem here -->
# ![m.png](data:image/png;base64,...)

# %% [markdown]
# # === Cell 3 - Assumptions & method ===

# %% [markdown]
# ### Assumption:
#
# - The following assumptions are made in this analysis:
#
# Continuous-time signal
# The variable
# 𝑡
# t is assumed to be continuous, and the signal is treated as a continuous-time signal.
#
# Sufficient sampling
# The number of samples (4000 points) is high enough to accurately represent the signal without noticeable distortion.
#
# Noise-free signal
# The signal is ideal and does not include any noise or external disturbances.
#
# Unit amplitudes
# Both sinusoidal components have an amplitude of 1.
#
# Linear superposition
# The signal is formed using linear addition, assuming a linear system where the principle of superposition applies.
# ### Methods used:
# - A time-domain approach was used to analyze the signal.
#
# A continuous time vector was generated using numpy.linspace over the interval
# 0
# ≤
# 𝑡
# ≤
# 8
# 0≤t≤8.
#
# The signal was constructed by linearly combining two sinusoidal functions: a cosine and a sine with different frequencies.
#
# Numerical sampling (4000 samples) was applied to approximate the continuous-time signal.
#
# The signal was visualized using Matplotlib by plotting the signal amplitude versus time.
#
# Grid, labels, and title were added to improve clarity and interpretation of the plot.
#  ### key details:
# - The signal is defined as:
#
# 𝑥
# (
# 𝑡
# )
# =
# cos
# ⁡
# (
# 2
# 𝜋
# 𝑡
# )
# +
# sin
# ⁡
# (
# 3
# 𝜋
# 𝑡
# )
# x(t)=cos(2πt)+sin(3πt)
#
# The signal consists of two sinusoidal components with different frequencies (1 Hz and 1.5 Hz).
#
# The combination of different frequencies results in a non-simple periodic waveform with a more complex shape.
#
# The time range
# 0
# ≤
# 𝑡
# ≤
# 8
# 0≤t≤8 is chosen to observe multiple repetitions of the waveform.
#
# A high number of samples (4000 points) ensures smooth and accurate plotting.
#
# The signal amplitude remains bounded, indicating a stable signal.
#
# The plot visually demonstrates constructive and destructive interference between the sinusoidal components.
#
# The signal is assumed to be noise-free and generated under ideal conditions.

# %% [markdown]
# # === Cell 4 - Solution Section ===

# %% [markdown]
# ### Cell 1: Import libraries
# numpy lets us create arrays and compute cosine/sine easily.
# matplotlib is used to draw the plots

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Cell 2: Define signal parameters
# Amplitude A=3
#
# Angular frequency 𝜔=2
#
# Period T=𝜋

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Cell 3: Create time vector
# linspace generates evenly spaced points.
# We cover
# 0≤t≤3𝜋

# %%
t = np.linspace(0, 8, 4000)

# %% [markdown]
# ### Cell 4: Compute real and imaginary parts
# Real part:3cos(2t)
#
# Imag part: 3sin(2t)

# %%
x = np.cos(2*np.pi*t) + np.sin(3*np.pi*t)

# %%
plt.figure(figsize=(8,4))

plt.plot(t, x)

plt.xlabel('t')

plt.ylabel('x(t)')

plt.title('x(t) = cos(2πt) + sin(3πt)  (4 periods)')

plt.grid(True)

plt.show()

# %% [markdown]
# ![Screenshot 2026-01-01 031015.png](data:image/png;base64,...)

# %% [markdown]
# ### Result:
# By running this code, the following signal is plotted:
#
# 𝑥
# (
# 𝑡
# )
# =
# cos
# ⁡
# (
# 2
# 𝜋
# 𝑡
# )
# +
# sin
# ⁡
# (
# 3
# 𝜋
# 𝑡
# )
# x(t)=cos(2πt)+sin(3πt)
# Conclusions:
#
# The signal is the sum of two sinusoidal waves with different frequencies:
#
# cos
# ⁡
# (
# 2
# 𝜋
# 𝑡
# )
# cos(2πt) has a frequency of 1 Hz
#
# sin
# ⁡
# (
# 3
# 𝜋
# 𝑡
# )
# sin(3πt) has a frequency of 1.5 Hz
#
# Since the frequencies are differerent, the resulting waveform is more complex than a single sinusoid.
#
# Over the time interval
#
# t=0 to
# 𝑡
# =
# 8
# t=8, the signal shows alternating constructive and destructive interference between the two components.
#
# The signal amplitude varies over time but remains bounded, meaning the signal is stable.
#
#
# ### Analysis:
# - the signal
# 𝑥
# (
# 𝑡
# )
# =
# cos
# ⁡
# (
# 2
# 𝜋
# 𝑡
# )
# +
# sin
# ⁡
# (
# 3
# 𝜋
# 𝑡
# )
# x(t)=cos(2πt)+sin(3πt) is composed of two sinusoidal components with frequencies 1 Hz and 1.5 Hz.
#
# Because the frequencies are different and not integer multiples, the resulting waveform is quasi-periodic, showing interference patterns:
#
# Constructive interference occurs when the peaks of both waves align, increasing amplitude.
#
# Destructive interference occurs when the peaks of one wave align with the troughs of the other, decreasing amplitude.
#
# The amplitude of the combined signal varies over time, but remains bounded (between -2 and +2).
#
# Over the chosen interval
# 𝑡
# =
# 0
# t=0 to
# 𝑡
# =
# 8
# t=8, multiple cycles of both waves are visible, allowing observation of their combined effect.
#
# Using dense sampling (4000 points) ensures a smooth and accurate visualization, preventing aliasing or jagged plots.
#
# This analysis shows how superposition of sinusoidal signals with different frequencies creates complex waveforms, which is a fundamental concept in signal processing.
